# %%
import pandas as pd
# %pylab inline

training_labels = pd.read_csv('./data/label_dataframes/training_labels.csv')
binary_labels = pd.read_csv('./data/label_dataframes/known_binary_labels.csv')

kraus2016_labels = binary_labels[binary_labels.source=='Kraus2016']
kolbl2015_labels = binary_labels[binary_labels.source=='Kolbl2015']
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# I don't really see a trend
rcParams.update({'legend.fontsize':12})
plot(training_labels.cks_steff, training_labels.cks_slogg, 'o', color='#D0D9D0', label='training set')
plot(kraus2016_labels.cks_steff, kraus2016_labels.cks_slogg, 'o', color='#4f67d3', label='imaged companions')
plot(kolbl2015_labels.cks_steff, kolbl2015_labels.cks_slogg, 'o', color='#E36B44', label='SB2s')
legend(loc='upper left', frameon=False)
xlabel(r'T$_{\rm eff}$ (K)')
ylabel('log g (dex)')
tight_layout()
xlim(7000,4000);ylim(4.8,2.7)
# Out:
# (4.8, 2.7)
